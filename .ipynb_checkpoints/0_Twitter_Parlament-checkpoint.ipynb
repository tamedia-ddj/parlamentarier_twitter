# %%
import pandas as pd
import numpy as np
import math
import requests
from bs4 import BeautifulSoup as bs
import time

# %%
### create function to find twitter-account with google query
def google_results(name, party):
    
    url = 'https://google.com/search?q={}+{}+twitter'.format(name.replace(" ", "+"), party)
    # ...wait for it....
    time.sleep(1)
    
    response = requests.get(url)
    soup = bs(response.text, 'html.parser')
    twitter_handle = soup.cite.text
    
    return twitter_handle

# %%
nationalrat = pd.read_html("https://de.wikipedia.org/wiki/Liste_der_Mitglieder_des_Schweizer_Nationalrats_in_der_50._Legislaturperiode")[0]
staenderat = pd.read_html("https://de.wikipedia.org/wiki/Liste_der_Mitglieder_des_Schweizer_St%C3%A4nderats_in_der_50._Legislaturperiode")[0]

# %%
nationalrat = nationalrat[["Name", "Partei", "Kanton"]]
nationalrat["Rat"] = "nr"

# %%
staenderat = staenderat[["Name", "Partei", "Kanton"]]
staenderat["Rat"] = "sr"

# %%
parlament = nationalrat.append(staenderat).reset_index().drop(columns=["index"])

# %%
twitter_info_list = []
for idx, row in parlament.iterrows():
    twitter_info_list.append([row["Name"], row["Partei"], google_results(row["Name"], row["Partei"])])

# %%
twitter_info = pd.DataFrame(twitter_info_list)
twitter_info.columns = ["name", "party", "url"]

# %%
def extract_handle(url):
    if (url.find("twitter") > -1):
        if len(url.split('/')) == 4:
            return(url.split('/')[3].split('?')[0])

# %%
twitter_info["twitter_handle"] = twitter_info.url.apply(extract_handle)

# %%
### export for manual corrections
twitter_info.to_csv("data/twitter_accounts_2019.csv")

# %%
### import corrected data
twitter_info_edited = pd.read_csv("data/twitter_accounts_2019_edited.csv", index_col=0)

# %%
twitter_users = twitter_info_edited[(twitter_info_edited['twitter_handle'].notnull())]

# %%
twitter_users = twitter_users.drop(columns = ["edited"])

# %%
import tweepy

# %%
consumer_key = "QiFcycH0Dkh2qUMKiEz6KagWy"
consumer_secret = "RJXtTYRe0lI47SXvTVcQZxnihOM7CQW88O9BptgWRWVOGQIlKU"
access_token = "20507198-nXLoFruaOgKrQZiorgJ8SJcISI9DLu1DETgHiiAWq"
access_token_secret = "YO2VQm3frJpVSCcjXFSGynQHeBMbKi3kjj1IkvKcXE3XA"
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

# %%
api = tweepy.API(auth)

# %%
user._json["id"]
# Out:
# 256863130

# %%
### Collect User-Ids
def get_twitter_id(username):
    user = api.get_user(username)
    return user._json["id"]
    
twitter_users["user_id"] = twitter_users.twitter_handle.apply(get_twitter_id)

# %%
twitter_users["user_id"] = twitter_users["user_id"].astype(str)

# %%
follower_list = pd.DataFrame(columns=["Name", "Party", "Handle", "Twitter_ID", "Follower_ID"])

# %%
for idx, row in twitter_users.iterrows():
    ids = []
    for page in tweepy.Cursor(api.followers_ids, screen_name=row.twitter_handle).pages():
        ids.extend(page)
        time.sleep(1)
    for follower in ids:
        if ((twitter_users['user_id'].astype(str) == str(follower)).any()):
            follower_list = follower_list.append(pd.DataFrame({"Name": row.name,
                                                               "Party": row.party,
                                                               "Handle": row.twitter_handle,
                                                               "Twitter_ID": row.user_id,
                                                               "Follower_ID": str(follower)
                                                              }, index=[0]), ignore_index=True)
    print(row.twitter_handle)
# Out:
# --------------------------------------
# KeyboardInterruptTraceback (most recent call last)
# <ipython-input-247-6e92bb43927f> in <module>
#      11                                            "Twitter_ID": row.user_id,
#      12                                            "Follower_ID": str(follower)
# ---> 13                                           }, index=[0]), ignore_index=True)
#
# ~/miniconda3/lib/python3.7/site-packages/pandas/core/frame.py in append(self, other, ignore_index, verify_integrity, sort)
#    6690         return concat(to_concat, ignore_index=ignore_index,
#    6691                       verify_integrity=verify_integrity,
# -> 6692                       sort=sort)
#    6693
#    6694     def join(self, other, on=None, how='left', lsuffix='', rsuffix='',
#
# ~/miniconda3/lib/python3.7/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     226                        keys=keys, levels=levels, names=names,
#     227                        verify_integrity=verify_integrity,
# --> 228                        copy=copy, sort=sort)
#     229     return op.get_result()
#     230
#
# ~/miniconda3/lib/python3.7/site-packages/pandas/core/reshape/concat.py in __init__(self, objs, axis, join, join_axes, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     290
#     291             # consolidate
# --> 292             obj._consolidate(inplace=True)
#     293             ndims.add(obj.ndim)
#     294
#
# ~/miniconda3/lib/python3.7/site-packages/pandas/core/generic.py in _consolidate(self, inplace)
#    5154         inplace = validate_bool_kwarg(inplace, 'inplace')
#    5155         if inplace:
# -> 5156             self._consolidate_inplace()
#    5157         else:
#    5158             f = lambda: self._data.consolidate()
#
# ~/miniconda3/lib/python3.7/site-packages/pandas/core/generic.py in _consolidate_inplace(self)
#    5136             self._data = self._data.consolidate()
#    5137
# -> 5138         self._protect_consolidate(f)
#    5139
#    5140     def _consolidate(self, inplace=False):
#
# ~/miniconda3/lib/python3.7/site-packages/pandas/core/generic.py in _protect_consolidate(self, f)
#    5125         """
#    5126         blocks_before = len(self._data.blocks)
# -> 5127         result = f()
#    5128         if len(self._data.blocks) != blocks_before:
#    5129             self._clear_item_cache()
#
# ~/miniconda3/lib/python3.7/site-packages/pandas/core/generic.py in f()
#    5134
#    5135         def f():
# -> 5136             self._data = self._data.consolidate()
#    5137
#    5138         self._protect_consolidate(f)
#
# ~/miniconda3/lib/python3.7/site-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    5078         try:
#    5079             object.__getattribute__(self, name)
# -> 5080             return object.__setattr__(self, name, value)
#    5081         except AttributeError:
#    5082             pass
#
# KeyboardInterrupt:

# %%
follower_list.to_pickle("data/follower_all.pkl")

# %%
follower_list = pd.read_pickle("data/follower_all.pkl")

# %%
follower_list_red = follower_list[follower_list['Follower_ID'].isin(twitter_users['user_id'].astype(str))]

# %%
followers_complete = pd.merge(follower_list_red,
                              twitter_users[["user_id", "name", "twitter_handle", "party"]],
                              left_on="Follower_ID",
                              right_on="user_id",
                              how="left")

# %%
# Re-Order and Clean DataFrame
followers_complete = pd.merge(followers_complete,
                             twitter_users[["name", "twitter_handle"]],
                             left_on="Handle",
                             right_on="twitter_handle",
                             how="left")

# %%
followers_complete = followers_complete[["name_y", "Name", "Party", "Handle", "Twitter_ID", "Follower_ID", "user_id", "name_x", "twitter_handle_x", "party", "twitter_handle_y"]]

# %%
followers_complete = followers_complete.drop(columns=["Name", "twitter_handle_y", "user_id"])

# %%
followers_complete.columns = ["user_Name", "user_Party", "user_Handle", "user_ID", "follower_ID", "follower_Name", "follower_Handle", "follower_Party"]

# %%
def party_scale(party):
    scale = {
        "sp": 1;
        "gps": 2;
        "evp": 3;
        "glp": 4;
        "cvp": 5;
        "bdp": 6;
        "fdp": 7;
        "lega": 8;
        "mcg": 9;
        "svp": 10
    }

# %%
followers_complete["user_Party_Scale"] = followers_complete["user_Party"].apply()
# Out:
#                user_Name user_Party  user_Handle     user_ID  \
# 0         Jean-Luc Addor        SVP      udcvr64   256863130
# 1         Jean-Luc Addor        SVP      udcvr64   256863130
# 2         Jean-Luc Addor        SVP      udcvr64   256863130
# 3         Jean-Luc Addor        SVP      udcvr64   256863130
# 4         Jean-Luc Addor        SVP      udcvr64   256863130
# 5         Jean-Luc Addor        SVP      udcvr64   256863130
# 6         Jean-Luc Addor        SVP      udcvr64   256863130
# 7         Jean-Luc Addor        SVP      udcvr64   256863130
# 8         Jean-Luc Addor        SVP      udcvr64   256863130
# 9         Jean-Luc Addor        SVP      udcvr64   256863130
# 10        Jean-Luc Addor        SVP      udcvr64   256863130
# 11        Jean-Luc Addor        SVP      udcvr64   256863130
# 12        Jean-Luc Addor        SVP      udcvr64   256863130
# 13        Jean-Luc Addor        SVP      udcvr64   256863130
# 14        Jean-Luc Addor        SVP      udcvr64   256863130
# 15        Jean-Luc Addor        SVP      udcvr64   256863130
# 16        Jean-Luc Addor        SVP      udcvr64   256863130
# 17        Jean-Luc Addor        SVP      udcvr64   256863130
# 18        Jean-Luc Addor        SVP      udcvr64   256863130
# 19        Jean-Luc Addor        SVP      udcvr64   256863130
# 20        Jean-Luc Addor        SVP      udcvr64   256863130
# 21    Matthias Aebischer         SP  m_aebischer   280789941
# 22    Matthias Aebischer         SP  m_aebischer   280789941
# 23    Matthias Aebischer         SP  m_aebischer   280789941
# 24    Matthias Aebischer         SP  m_aebischer   280789941
# 25    Matthias Aebischer         SP  m_aebischer   280789941
# 26    Matthias Aebischer         SP  m_aebischer   280789941
# 27    Matthias Aebischer         SP  m_aebischer   280789941
# 28    Matthias Aebischer         SP  m_aebischer   280789941
# 29    Matthias Aebischer         SP  m_aebischer   280789941
# ...                  ...        ...          ...         ...
# 3345        Samira Marti         SP  samiramarti  1690746518
# 3346        Samira Marti         SP  samiramarti  1690746518
# 3347        Samira Marti         SP  samiramarti  1690746518
# 3348        Samira Marti         SP  samiramarti  1690746518
# 3349        Samira Marti         SP  samiramarti  1690746518
# 3350        Samira Marti         SP  samiramarti  1690746518
# 3351        Samira Marti         SP  samiramarti  1690746518
# 3352        Samira Marti         SP  samiramarti  1690746518
# 3353        Samira Marti         SP  samiramarti  1690746518
# 3354        Samira Marti         SP  samiramarti  1690746518
# 3355        Samira Marti         SP  samiramarti  1690746518
# 3356        Samira Marti         SP  samiramarti  1690746518
# 3357        Samira Marti         SP  samiramarti  1690746518
# 3358        Samira Marti         SP  samiramarti  1690746518
# 3359        Samira Marti         SP  samiramarti  1690746518
# 3360        Samira Marti         SP  samiramarti  1690746518
# 3361        Samira Marti         SP  samiramarti  1690746518
# 3362        Samira Marti         SP  samiramarti  1690746518
# 3363        Samira Marti         SP  samiramarti  1690746518
# 3364        Samira Marti         SP  samiramarti  1690746518
# 3365    Nadine Masshardt         SP   nmasshardt  1228066279
# 3366    Nadine Masshardt         SP   nmasshardt  1228066279
# 3367    Nadine Masshardt         SP   nmasshardt  1228066279
# 3368    Nadine Masshardt         SP   nmasshardt  1228066279
# 3369    Nadine Masshardt         SP   nmasshardt  1228066279
# 3370    Nadine Masshardt         SP   nmasshardt  1228066279
# 3371    Nadine Masshardt         SP   nmasshardt  1228066279
# 3372    Nadine Masshardt         SP   nmasshardt  1228066279
# 3373    Nadine Masshardt         SP   nmasshardt  1228066279
# 3374    Nadine Masshardt         SP   nmasshardt  1228066279
#
#               follower_ID             follower_Name  follower_Handle  \
# 0               605639477              Franz Grüter         fgrueter
# 1               289393019              Marco Chiesa    marcochiesa74
# 2                50444931    Christian Wasserfallen            cwasi
# 3      888380018673545216              Thomas Egger  thomas_egger_nr
# 4               485885985            Manuel Tornare    manueltornare
# 5               815578430       Jacques-André Maire        mairejack
# 6               213648250   Brigitte Häberli-Koller       b_haeberli
# 7                40872955          Christian Levrat  christianlevrat
# 8               222903677           Christian Imark   christianimark
# 9               991720068             Fabio Regazzi         fregazzi
# 10               26531313             Lukas Reimann     lukasreimann
# 11              385293664        Barbara Steinemann   babasteinemann
# 12              123362849                Beat Flach        beatflach
# 13              121068845           Claudio Zanetti          zac1967
# 14             2449367689  Géraldine Marchand-Balet  gmarchand_balet
# 15             2317281625           Benjamin Roduit   roduitbenjamin
# 16             2172700965            Manfred Bühler     buehler4bern
# 17              406232148           Mathias Reynard   mathiasreynard
# 18               96339142    Philipp Matthias Bregy          pmbregy
# 19              190944081            Natalie Rickli    natalierickli
# 20               20442734        Philippe Nantermod        nantermod
# 21    1090960191963742208                Kurt Fluri        FluriKurt
# 22     888380018673545216              Thomas Egger  thomas_egger_nr
# 23     731908201592045568             Thomas Aeschi    thomas_aeschi
# 24             3257088023              Sibel Arslan    sibelarslanbs
# 25     969185938898345985        Heinz Siegenthaler   h_siegenthaler
# 26     976446961292402689          Werner Luginbühl     w_luginbuehl
# 27              716002872          Matthias Jauslin  JauslinMatthias
# 28     968401772732735488              Duri Campell     duri_campell
# 29             2353332248             Michael Töngi          mtoengi
# ...                   ...                       ...              ...
# 3345            121068845           Claudio Zanetti          zac1967
# 3346            246714911       Edith Graf-Litscher        edithgraf
# 3347           1228066279          Nadine Masshardt       nmasshardt
# 3348            847717320  Marina Carobbio Guscetti   marinacarobbio
# 3349            921948812       Flavia Wasserfallen    fwasserfallen
# 3350            264811652               Aline Trede       alinetrede
# 3351           2536865558              Barbara Gysi           bagysi
# 3352           2913929512          Kathrin Bertschy  kathrinbertschy
# 3353             50047040         Jacqueline Badran        jaybadran
# 3354           2881577681              Mattea Meyer     meyer_mattea
# 3355           3374457514                 Maya Graf      nr_mayagraf
# 3356            107053461              Min Li Marti       minlimarti
# 3357           3246291543           Daniel Jositsch   danieljositsch
# 3358           1052528581           Eric Nussbaumer          enussbi
# 3359             21436172            Cédric Wermuth    cedricwermuth
# 3360            227087638               Yvonne Feri            yferi
# 3361            303319566           Silvia Schenker   schenkersilvia
# 3362            406232148           Mathias Reynard   mathiasreynard
# 3363            778644518            Roger Nordmann    nordmannroger
# 3364           1095889302             Fabian Molina        molinafab
# 3365            350198606           Roberta Pantani        robipanta
# 3366            121068845           Claudio Zanetti          zac1967
# 3367            716002872          Matthias Jauslin  JauslinMatthias
# 3368  1090960191963742208                Kurt Fluri        FluriKurt
# 3369   731908201592045568             Thomas Aeschi    thomas_aeschi
# 3370           3082560978  Laurence Fehlmann Rielle   fehlmannrielle
# 3371   969185938898345985        Heinz Siegenthaler   h_siegenthaler
# 3372           2353332248             Michael Töngi          mtoengi
# 3373            222903677           Christian Imark   christianimark
# 3374           1690746518              Samira Marti      samiramarti
#
#      follower_Party
# 0               SVP
# 1               SVP
# 2               FDP
# 3               CVP
# 4                SP
# 5                SP
# 6               CVP
# 7                SP
# 8               SVP
# 9               CVP
# 10              SVP
# 11              SVP
# 12              glp
# 13              SVP
# 14              CVP
# 15              CVP
# 16              SVP
# 17               SP
# 18              CVP
# 19              SVP
# 20              FDP
# 21              FDP
# 22              CVP
# 23              SVP
# 24              GPS
# 25              BDP
# 26              BDP
# 27              FDP
# 28              BDP
# 29              GPS
# ...             ...
# 3345            SVP
# 3346             SP
# 3347             SP
# 3348             SP
# 3349             SP
# 3350            GPS
# 3351             SP
# 3352            glp
# 3353             SP
# 3354             SP
# 3355            GPS
# 3356             SP
# 3357             SP
# 3358             SP
# 3359             SP
# 3360             SP
# 3361             SP
# 3362             SP
# 3363             SP
# 3364             SP
# 3365           Lega
# 3366            SVP
# 3367            FDP
# 3368            FDP
# 3369            SVP
# 3370             SP
# 3371            BDP
# 3372            GPS
# 3373            SVP
# 3374             SP
#
# [3375 rows x 8 columns]

# %%
parlament_2 = pd.read_excel("data/mitgliederlist-pc.xls")
# Out:
# WARNING *** file size (139136) not 512 + multiple of sector size (512)

# %%
names = parlament_2[["Vorname", "Name"]]

# %%
names["Full_Name"] = names["Vorname"] + " " + names["Name"]
# Out:
# /Users/sco/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
(set(names["Full_Name"]) - set(twitter_info_edited.name))
# Out:
# {'Andrea Gmür-Schönenberger',
#  'Andrea Martina Geissbühler',
#  'Gregor Rutz',
#  'Jean-Pierre Grin',
#  'Matthias Samuel Jauslin',
#  'Mike Egger',
#  'Niklaus-Samuel Gugger',
#  'Pascale Bruderer Wyss',
#  'Philipp Matthias Bregy',
#  'Ruth Humbel',
#  'Sandra Sollberger'}

# %%
(set(twitter_info_edited.name) - set(names["Full_Name"]))
# Out:
# {'Andrea Geissbühler',
#  'Andrea Gmür',
#  'Gregor A. Rutz',
#  'Jean-Pierre Grin-Hofmann',
#  'Matthias Jauslin',
#  'Nik Gugger',
#  'Pascale Bruderer',
#  'Rebecca Ruiz',
#  'Ruth Humbel Näf',
#  'Sandra Sollberger-Muff'}
